# %% [markdown]
# # Initialization

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType
from pyspark.sql.functions import trim, col

# %% [markdown]
# # Read Bronze Table

# %%
df = spark.table("databricks_medallion_pipeline.bronze.crm_cust_info")

# %% [markdown]
# # Silver Transformations

# %% [markdown]
# ##Trimming

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df = df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# ##Normalization

# %%
df = (
        df
        .withColumn(
            "cst_marital_status",
            F.when(F.upper(col("cst_marital_status")) == "M", "Married")
             .when(F.upper(col("cst_marital_status")) == "S", "Single")
             .otherwise("n/a")
        )
        .withColumn(
            "cst_gndr",
            F.when(F.upper(col("cst_gndr")) == "M", "Male")
             .when(F.upper(col("cst_gndr")) == "F", "Female")
             .otherwise("n/a")
        )
    )

# %% [markdown]
# ## Remove Records with Missing Customer ID

# %%
df = df.filter(col("cst_id").isNotNull())

# %% [markdown]
# # Renaming Columns

# %%
RENAME_DICT = {
    "cst_id": "customer_id",
    "cst_key": "customer_number",
    "cst_firstname": "first_name",
    "cst_lastname": "last_name",
    "cst_marital_status": "marital_status",
    "cst_gndr": "gender",
    "cst_create_date": "created_date"
}

for old_name, new_name in RENAME_DICT.items():
    df = df.withColumnRenamed(old_name, new_name)

# %% [markdown]
# #Verifying Dataframe and Saving

# %% [markdown]
# ## Printing 10 rows for verification

# %%
df.limit(10).display()

# %% [markdown]
# ##Writing Silver Table

# %%
df.write.mode("overwrite").format("delta").saveAsTable("databricks_medallion_pipeline.silver.crm_customers")

# %% [markdown]
# #Verifying Saved Table

# %%
# %sql
SELECT * FROM databricks_medallion_pipeline.silver.crm_customers LIMIT 10
