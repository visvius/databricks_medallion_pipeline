# %% [markdown]
# # Initialization

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType
from pyspark.sql.functions import trim, col

# %% [markdown]
# # Read Bronze Table

# %%
df = spark.table("databricks_medallion_pipeline.bronze.erp_cust_az12")
df.limit(10).display()

# %% [markdown]
# # Silver Transformations

# %% [markdown]
# ##Trimming

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# ##Customer ID Cleanup

# %%
# Removing NAS if its starts with it
df = df.withColumn(
    "cid",
    F.when(col("cid").startswith("NAS"),
           F.substring(col("cid"), 4, F.length(col("cid"))))
     .otherwise(col("cid"))
)

# %% [markdown]
# ## Birthdate Validation

# %%
df = df.withColumn(
    "bdate",
    F.when(col("bdate") > F.current_date(), None)
     .otherwise(col("bdate"))
)

# %% [markdown]
# ##Gender Normalization

# %%
df = df.withColumn(
    "gen",
    F.when(F.upper(col("gen")).isin("F", "FEMALE"), "Female")
     .when(F.upper(col("gen")).isin("M", "MALE"), "Male")
     .otherwise("n/a")
)

# %% [markdown]
# # Renaming Columns

# %%
RENAME_MAP = {
    "cid": "customer_number",
    "bdate": "birth_date",
    "gen": "gender"
}
for old_name, new_name in RENAME_MAP.items():
    df = df.withColumnRenamed(old_name, new_name)

# %% [markdown]
# #Verifying Dataframe and Saving

# %% [markdown]
# ## Printing rows for verification

# %%
df.limit(10).display()

# %% [markdown]
# ##Writing Silver Table

# %%
df.write.mode("overwrite").format("delta").saveAsTable("databricks_medallion_pipeline.silver.erp_customers")

# %% [markdown]
# #Verifying Saved Table

# %%
# %sql
SELECT * FROM databricks_medallion_pipeline.silver.erp_customers
