# %% [markdown]
# #Delete ALL Bronze Tables

# %%
catalog_name = "databricks_medallion_pipeline"
schema_name = "bronze"
tables_to_drop = [
    "crm_cust_info",
    "crm_prd_info",
    "crm_sales_details",
    "erp_cust_az12",
    "erp_loc_a101",
    "erp_px_cat_g1v2"
]

for table_name in tables_to_drop:
    full_table_path = f"{catalog_name}.{schema_name}.{table_name}"
    
    print(f"Dropping table: {full_table_path}")
    spark.sql(f"DROP TABLE IF EXISTS {full_table_path}")

# %% [markdown]
# #Delete ALL Silver Tables

# %%
catalog_name = "databricks_medallion_pipeline"
schema_name = "silver"
tables_to_drop = [
    "crm_customers",
    "crm_products",
    "crm_sales",
    "erp_customer_location",
    "erp_customers",
    "erp_product_category"
]

for table_name in tables_to_drop:
    full_table_path = f"{catalog_name}.{schema_name}.{table_name}"
    
    print(f"Dropping table: {full_table_path}")
    spark.sql(f"DROP TABLE IF EXISTS {full_table_path}")

# %% [markdown]
# #Delete ALL Gold Tables

# %%
catalog_name = "databricks_medallion_pipeline"
schema_name = "gold"
tables_to_drop = [
    "dim_customers",
    "dim_products",
    "fact_sales"
]

for table_name in tables_to_drop:
    full_table_path = f"{catalog_name}.{schema_name}.{table_name}"
    
    print(f"Dropping table: {full_table_path}")
    spark.sql(f"DROP TABLE IF EXISTS {full_table_path}")
