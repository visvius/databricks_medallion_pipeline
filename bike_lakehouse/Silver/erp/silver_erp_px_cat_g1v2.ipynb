# %% [markdown]
# # Initialization

# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType
from pyspark.sql.functions import trim, col

# %% [markdown]
# # Read Bronze Table

# %%
df = spark.table("databricks_medallion_pipeline.bronze.erp_px_cat_g1v2")
df.limit(10).display()

# %% [markdown]
# # Silver Transformations

# %% [markdown]
# ##Trimming

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# ## Normalize Maintenance Flag to Boolean

# %%
df = df.withColumn(
    "maintenance",
    F.when(F.upper(col("maintenance")) == "YES", F.lit(True))
     .when(F.upper(col("maintenance")) == "NO", F.lit(False))
     .otherwise(None)
)

# %% [markdown]
# # Renaming Columns

# %%
RENAME_MAP = {
    "id": "category_id",
    "cat": "category",
    "subcat": "subcategory",
    "maintenance": "maintenance_flag"
}
for old_name, new_name in RENAME_MAP.items():
    df = df.withColumnRenamed(old_name, new_name)

# %% [markdown]
# #Verifying Dataframe and Saving

# %% [markdown]
# ## Printing rows for verification

# %%
df.limit(10).display()

# %% [markdown]
# ##Writing Silver Table

# %%
df.write.mode("overwrite").format("delta").saveAsTable("databricks_medallion_pipeline.silver.erp_product_category")

# %% [markdown]
# #Verifying Saved Table

# %%
# %sql
SELECT * FROM databricks_medallion_pipeline.silver.erp_product_category LIMIT 10
